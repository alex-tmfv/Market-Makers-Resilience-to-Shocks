# %% [markdown]
# # Обзор шоковых сценариев
#
# | # | Сценарий |
# |---|---|
# | 1 | Stationary |
# | 2 | Megashock |
# | 3 | Drift down |
# | 4 | Drift up |
# | 5 | News-shock |
# | 6 | Liquidity shock A_USD bid |
# | 7 | FX-shock |

# %%
# %matplotlib inline
import os
import sys
from pathlib import Path

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import matplotlib.pyplot as plt

from src.analysis import plots

LOGS_BASE = Path(PROJECT_ROOT) / 'experiments' / 'log'

# %% [markdown]
# ## 1. Stationary

# %%
fig = plots.plot_bid_ask_mid('baseline_seed48', base=LOGS_BASE)
plt.show()

# %% [markdown]
# ## 2. Small Shocks

# %%
fig = plots.plot_bid_ask_mid_with_reference('megashock_seed48', 'baseline_seed48', base=LOGS_BASE)
plt.show()

# %% [markdown]
# ## 3. Drift down

# %%
fig = plots.plot_bid_ask_mid_with_reference('drift_down_seed48', 'baseline_seed48', base=LOGS_BASE)
plt.show()

# %% [markdown]
# ## 4. Drift up

# %%
fig = plots.plot_bid_ask_mid_with_reference('drift_up_seed48', 'baseline_seed48', base=LOGS_BASE)
plt.show()

# %% [markdown]
# ## 5. News-shock / Mega Shock

# %%
fig = plots.plot_bid_ask_mid_with_reference('news_shock_seed48', 'baseline_seed48', base=LOGS_BASE)
plt.show()

# %% [markdown]
# ## 6. Liquidity shock

# %%
fig = plots.plot_bid_ask_mid_with_reference('liquidity_crisis_seed48', 'baseline_seed48', base=LOGS_BASE)
plt.show()

# %% [markdown]
# ## 7. FX-shock

# %%
fig = plots.plot_bid_ask_mid_with_reference('fx_shock_seed48', 'baseline_seed48', base=LOGS_BASE)
plt.show()
